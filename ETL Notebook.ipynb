# %%
#Import dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
#Import csv file and read into dataframe
file = 'wine-reviews/sample_wine_data.csv'
wine_df = pd.read_csv(file, encoding="ISO-8859-1")
wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                     VulkÃÂ  Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2           taster_name  \
# 0                 Etna                NaN  Kerin OÃ¢â¬â¢Keefe
# 1                  NaN                NaN            Roger Voss
# 2    Willamette Valley  Willamette Valley          Paul Gregutt
# 3  Lake Michigan Shore                NaN    Alexander Peartree
# 4    Willamette Valley  Willamette Valley          Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe               Nicosia 2013 VulkÃÂ  Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        @paulgwineÃÂ       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        @paulgwineÃÂ   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
#Drop all null values
not_null_wine_df= wine_df.dropna(how='any')
not_null_wine_df.head()
# Out:
#     Unnamed: 0 country                                        description  \
# 4            4      US  Much like the regular bottling from 2012, this...
# 10          10      US  Soft, supple plum envelopes an oaky structure ...
# 23          23      US  This wine from the Geneseo district offers aro...
# 25          25      US  Oak and earth intermingle around robust aromas...
# 35          35      US  As with many of the Erath 2010 vineyard design...
#
#                            designation  points  price    province  \
# 4   Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10                   Mountain CuvÃÂ©e      87   19.0  California
# 23                 Signature Selection      87   22.0  California
# 25                 King Ridge Vineyard      87   69.0  California
# 35                              Hyland      86   50.0      Oregon
#
#              region_1           region_2     taster_name  \
# 4   Willamette Valley  Willamette Valley    Paul Gregutt
# 10        Napa Valley               Napa  Virginie Boone
# 23        Paso Robles      Central Coast   Matt Kettmann
# 25       Sonoma Coast             Sonoma  Virginie Boone
# 35        McMinnville  Willamette Valley    Paul Gregutt
#
#    taster_twitter_handle                                              title  \
# 4         @paulgwineÃÂ   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 10               @vboone  Kirkland Signature 2011 Mountain CuvÃÂ©e Cabe...
# 23         @mattkettmann  Bianchi 2011 Signature Selection Merlot (Paso ...
# 25               @vboone  Castello di Amorosa 2011 King Ridge Vineyard P...
# 35        @paulgwineÃÂ          Erath 2010 Hyland Pinot Noir (McMinnville)
#
#                variety               winery
# 4           Pinot Noir         Sweet Cheeks
# 10  Cabernet Sauvignon   Kirkland Signature
# 23              Merlot              Bianchi
# 25          Pinot Noir  Castello di Amorosa
# 35          Pinot Noir                Erath

# %%
#Check column names
not_null_wine_df.count()
# Out:
# Unnamed: 0               24
# country                  24
# description              24
# designation              24
# points                   24
# price                    24
# province                 24
# region_1                 24
# region_2                 24
# taster_name              24
# taster_twitter_handle    24
# title                    24
# variety                  24
# winery                   24
# dtype: int64

# %%
#Drop extra columns in dataframe
cleaned_wine_df= not_null_wine_df.drop(['Unnamed: 0','description','region_2','taster_twitter_handle'], axis=1)
cleaned_wine_df.head()
# Out:
#    country                         designation  points  price    province  \
# 4       US  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10      US                   Mountain CuvÃÂ©e      87   19.0  California
# 23      US                 Signature Selection      87   22.0  California
# 25      US                 King Ridge Vineyard      87   69.0  California
# 35      US                              Hyland      86   50.0      Oregon
#
#              region_1     taster_name  \
# 4   Willamette Valley    Paul Gregutt
# 10        Napa Valley  Virginie Boone
# 23        Paso Robles   Matt Kettmann
# 25       Sonoma Coast  Virginie Boone
# 35        McMinnville    Paul Gregutt
#
#                                                 title             variety  \
# 4   Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 10  Kirkland Signature 2011 Mountain CuvÃÂ©e Cabe...  Cabernet Sauvignon
# 23  Bianchi 2011 Signature Selection Merlot (Paso ...              Merlot
# 25  Castello di Amorosa 2011 King Ridge Vineyard P...          Pinot Noir
# 35         Erath 2010 Hyland Pinot Noir (McMinnville)          Pinot Noir
#
#                  winery
# 4          Sweet Cheeks
# 10   Kirkland Signature
# 23              Bianchi
# 25  Castello di Amorosa
# 35                Erath

# %%
#Double check consistency in price column to determine data type
cleaned_wine_df['price'].head(50)
# Out:
# 4       65.0
# 10      19.0
# 23      22.0
# 25      69.0
# 35      50.0
# 60     100.0
# 62      25.0
# 64      26.0
# 67      46.0
# 71      40.0
# 73      75.0
# 74      55.0
# 75      75.0
# 78      25.0
# 84      24.0
# 87      55.0
# 90      23.0
# 92      55.0
# 94      22.0
# 99      75.0
# 108     26.0
# 111     85.0
# 114     18.0
# 116     25.0
# Name: price, dtype: float64

# %%
#Connect to database
wine_connection_string = "postgres:Bruh1need@pwd@localhost:5432/wine_db"
engine = create_engine(f'postgresql://{wine_connection_string}')

# %%
#Check table names
engine.table_names()
# Out:
# ['wine_table']

# %%
#Convert cleaned dataframe to database
cleaned_wine_df.to_sql(name='wine_table', con=engine, if_exists='append', index=False)

# %%
#Confirm data had been added into database
pd.read_sql_query('select * from wine_table', con=engine).head()
# Out:
#   country                         designation  points  price    province  \
# 0      US  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 1      US                     Mountain CuvÃ©e      87   19.0  California
# 2      US                 Signature Selection      87   22.0  California
# 3      US                 King Ridge Vineyard      87   69.0  California
# 4      US                              Hyland      86   50.0      Oregon
#
#             region_1     taster_name  \
# 0  Willamette Valley    Paul Gregutt
# 1        Napa Valley  Virginie Boone
# 2        Paso Robles   Matt Kettmann
# 3       Sonoma Coast  Virginie Boone
# 4        McMinnville    Paul Gregutt
#
#                                                title             variety  \
# 0  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 1  Kirkland Signature 2011 Mountain CuvÃ©e Cabern...  Cabernet Sauvignon
# 2  Bianchi 2011 Signature Selection Merlot (Paso ...              Merlot
# 3  Castello di Amorosa 2011 King Ridge Vineyard P...          Pinot Noir
# 4         Erath 2010 Hyland Pinot Noir (McMinnville)          Pinot Noir
#
#                 winery
# 0         Sweet Cheeks
# 1   Kirkland Signature
# 2              Bianchi
# 3  Castello di Amorosa
# 4                Erath
