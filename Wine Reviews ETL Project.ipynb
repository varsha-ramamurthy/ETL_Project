# %%
#Import dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
#Import wine reviews csv files and read into dataframe
kaggle_wine_file = 'Resources/wine-reviews/winemag-data-130k-v2.csv'
kaggle_wine_df = pd.read_csv(kaggle_wine_file, encoding="ISO-8859-1")
data_world_wine_file = 'Resources/Wines.csv'
data_world_wine_df = pd.read_csv(data_world_wine_file, encoding="ISO-8859-1")

# %%
#Display both dataframes
kaggle_wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                       VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN     Kerin OâKeefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                 Nicosia 2013 VulkÃ  Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2          @paulgwineÂ       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4          @paulgwineÂ   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
data_world_wine_df.head()
# Out:
#     Vintage   Country                           County          Designation  \
# 0  1/1/1919     Spain                             Cava  1919 Brut SelecciÃ³
# 1  1/1/1929     Italy       Vernaccia di San Gimignano                  NaN
# 2  1/1/1929     Italy  Sangiovese di Romagna Superiore             Prugneto
# 3  1/1/1934  Portugal                              NaN        Reserva Velho
# 4  1/1/1945    France                       Rivesaltes       Legend Vintage
#
#    Points    Price              Province  \
# 0      88   $13.00             Catalonia
# 1      87   $14.00               Tuscany
# 2      84   $15.00         Central Italy
# 3      93  $495.00               Colares
# 4      95  $350.00  Languedoc-Roussillon
#
#                                                Title          Variety  \
# 0    L'Arboc NV 1919 Brut SelecciÃ³ Sparkling (Cava)  Sparkling Blend
# 1         Guidi 1929 2015 Vernaccia di San Gimignano        Vernaccia
# 2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...       Sangiovese
# 3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...          Ramisco
# 4  GÃ©rard Bertrand 1945 Legend Vintage Red (Rive...        Red Blend
#
#                     Winery
# 0                  L'Arboc
# 1               Guidi 1929
# 2  Poderi dal Nespoli 1929
# 3        Adega Viuva Gomes
# 4         GÃ©rard Bertrand

# %%
#Adjust case sensitive columns
kaggle_wine_df = kaggle_wine_df.rename(columns={"country": "Country", "designation": "Designation", "points": "Points", "price": "Price", "province": "Province", "title": "Title", "variety": "Variety", "winery": "Winery"})

# %%
#Merge the two dataframes
merged_wine_df = pd.merge(kaggle_wine_df, data_world_wine_df, on="Title")
#'Designation', 'Points', 'Price', 'Province', 'Title', 'Variety', 'Winery'])
merged_wine_df.head()
# Out:
#    Unnamed: 0  Country_x                                        description  \
# 0           4         US  Much like the regular bottling from 2012, this...
# 1           6      Italy  Here's a bright, informal red that opens with ...
# 2          11     France  This is a dry wine, very spicy, with a tight, ...
# 3      102760     France  This is a dry wine, very spicy, with a tight, ...
# 4          17  Argentina  Raw black-cherry aromas are direct and simple ...
#
#                         Designation_x  Points_x  Price_x         Province_x  \
# 0  Vintner's Reserve Wild Child Block        87     65.0             Oregon
# 1                             Belsito        87     16.0  Sicily & Sardinia
# 2                                 NaN        87     30.0             Alsace
# 3                                 NaN        87     30.0             Alsace
# 4                 Winemaker Selection        87     13.0   Mendoza Province
#
#             region_1           region_2        taster_name  ...  \
# 0  Willamette Valley  Willamette Valley       Paul Gregutt  ...
# 1           Vittoria                NaN    Kerin OâKeefe  ...
# 2             Alsace                NaN         Roger Voss  ...
# 3             Alsace                NaN         Roger Voss  ...
# 4            Mendoza                NaN  Michael Schachner  ...
#
#           Winery_x   Vintage  Country_y             County  \
# 0     Sweet Cheeks  1/1/2012         US  Willamette Valley
# 1  Terre di Giurfo  1/1/2013      Italy           Vittoria
# 2       Leon Beyer  1/1/2012     France             Alsace
# 3       Leon Beyer  1/1/2012     France             Alsace
# 4    Gaucho Andino  1/1/2011  Argentina            Mendoza
#
#                         Designation_y Points_y Price_y         Province_y  \
# 0  Vintner's Reserve Wild Child Block       87  $65.00             Oregon
# 1                             Belsito       87  $16.00  Sicily & Sardinia
# 2                                 NaN       87  $30.00             Alsace
# 3                                 NaN       87  $30.00             Alsace
# 4                 Winemaker Selection       87  $13.00   Mendoza Province
#
#          Variety_y         Winery_y
# 0       Pinot Noir     Sweet Cheeks
# 1         Frappato  Terre di Giurfo
# 2  GewÃ¼rztraminer       Leon Beyer
# 3  GewÃ¼rztraminer       Leon Beyer
# 4           Malbec    Gaucho Andino
#
# [5 rows x 23 columns]

# %%
#Drop all null values from the merged dataframe
not_null_wine_df= merged_wine_df.dropna(how='any')
not_null_wine_df.head()
# Out:
#     Unnamed: 0 Country_x                                        description  \
# 0            4        US  Much like the regular bottling from 2012, this...
# 7           23        US  This wine from the Geneseo district offers aro...
# 8       102755        US  This wine from the Geneseo district offers aro...
# 21          62        US  The aromas are brooding, with notes of barrel ...
# 22          64        US  There are intriguing touches to the nose of th...
#
#                          Designation_x  Points_x  Price_x  Province_x  \
# 0   Vintner's Reserve Wild Child Block        87     65.0      Oregon
# 7                  Signature Selection        87     22.0  California
# 8                  Signature Selection        87     22.0  California
# 21                Alder Ridge Vineyard        86     25.0  Washington
# 22                         Golden Horn        86     26.0  California
#
#                 region_1           region_2       taster_name  ...  \
# 0      Willamette Valley  Willamette Valley      Paul Gregutt  ...
# 7            Paso Robles      Central Coast     Matt Kettmann  ...
# 8            Paso Robles      Central Coast     Matt Kettmann  ...
# 21  Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan  ...
# 22     Santa Ynez Valley      Central Coast     Matt Kettmann  ...
#
#         Winery_x   Vintage Country_y                County  \
# 0   Sweet Cheeks  1/1/2012        US     Willamette Valley
# 7        Bianchi  1/1/2011        US           Paso Robles
# 8        Bianchi  1/1/2011        US           Paso Robles
# 21           Ram  1/1/2014        US  Columbia Valley (WA)
# 22        Sevtap  1/1/2015        US     Santa Ynez Valley
#
#                          Designation_y Points_y Price_y  Province_y  \
# 0   Vintner's Reserve Wild Child Block       87  $65.00      Oregon
# 7                  Signature Selection       87  $22.00  California
# 8                  Signature Selection       87  $22.00  California
# 21                Alder Ridge Vineyard       86  $25.00  Washington
# 22                         Golden Horn       86  $26.00  California
#
#           Variety_y      Winery_y
# 0        Pinot Noir  Sweet Cheeks
# 7            Merlot       Bianchi
# 8            Merlot       Bianchi
# 21   Cabernet Franc           Ram
# 22  Sauvignon Blanc        Sevtap
#
# [5 rows x 23 columns]

# %%
#Drop extra columns in dataframe
cleaned_wine_df= not_null_wine_df.drop(['Unnamed: 0','description','region_2','taster_twitter_handle', 'Country_y', 'Designation_y', 'Points_y', 'Price_y', 'Province_y', 'Variety_y', 'Winery_y'], axis=1)
cleaned_wine_df.head()
# Out:
#    Country_x                       Designation_x  Points_x  Price_x  \
# 0         US  Vintner's Reserve Wild Child Block        87     65.0
# 7         US                 Signature Selection        87     22.0
# 8         US                 Signature Selection        87     22.0
# 21        US                Alder Ridge Vineyard        86     25.0
# 22        US                         Golden Horn        86     26.0
#
#     Province_x              region_1       taster_name  \
# 0       Oregon     Willamette Valley      Paul Gregutt
# 7   California           Paso Robles     Matt Kettmann
# 8   California           Paso Robles     Matt Kettmann
# 21  Washington  Columbia Valley (WA)  Sean P. Sullivan
# 22  California     Santa Ynez Valley     Matt Kettmann
#
#                                                 Title        Variety_x  \
# 0   Sweet Cheeks 2012 Vintner's Reserve Wild Child...       Pinot Noir
# 7   Bianchi 2011 Signature Selection Merlot (Paso ...           Merlot
# 8   Bianchi 2011 Signature Selection Merlot (Paso ...           Merlot
# 21  Ram 2014 Alder Ridge Vineyard Cabernet Franc (...   Cabernet Franc
# 22  Sevtap 2015 Golden Horn Sauvignon Blanc (Santa...  Sauvignon Blanc
#
#         Winery_x   Vintage                County
# 0   Sweet Cheeks  1/1/2012     Willamette Valley
# 7        Bianchi  1/1/2011           Paso Robles
# 8        Bianchi  1/1/2011           Paso Robles
# 21           Ram  1/1/2014  Columbia Valley (WA)
# 22        Sevtap  1/1/2015     Santa Ynez Valley

# %%
#Rename columns
cleaned_wine_df = cleaned_wine_df.rename(columns={"Country_x": "country", "Designation_x": "designation", "Points_x": "points", "Price_x": "price", "Province_x": "province", "Variety_x": "variety", "Winery_x": "winery", "Title": "title", "Vintage": "vintage", "County": "county", "region_1": "region"})
cleaned_wine_df.head()
# Out:
#    country                         designation  points  price    province  \
# 0       US  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 7       US                 Signature Selection      87   22.0  California
# 8       US                 Signature Selection      87   22.0  California
# 21      US                Alder Ridge Vineyard      86   25.0  Washington
# 22      US                         Golden Horn      86   26.0  California
#
#                   region       taster_name  \
# 0      Willamette Valley      Paul Gregutt
# 7            Paso Robles     Matt Kettmann
# 8            Paso Robles     Matt Kettmann
# 21  Columbia Valley (WA)  Sean P. Sullivan
# 22     Santa Ynez Valley     Matt Kettmann
#
#                                                 title          variety  \
# 0   Sweet Cheeks 2012 Vintner's Reserve Wild Child...       Pinot Noir
# 7   Bianchi 2011 Signature Selection Merlot (Paso ...           Merlot
# 8   Bianchi 2011 Signature Selection Merlot (Paso ...           Merlot
# 21  Ram 2014 Alder Ridge Vineyard Cabernet Franc (...   Cabernet Franc
# 22  Sevtap 2015 Golden Horn Sauvignon Blanc (Santa...  Sauvignon Blanc
#
#           winery   vintage                county
# 0   Sweet Cheeks  1/1/2012     Willamette Valley
# 7        Bianchi  1/1/2011           Paso Robles
# 8        Bianchi  1/1/2011           Paso Robles
# 21           Ram  1/1/2014  Columbia Valley (WA)
# 22        Sevtap  1/1/2015     Santa Ynez Valley

# %%
#Connect to database
wine_connection_string = "postgres:Bruh1need@pwd@localhost:5432/wine_db"
engine = create_engine(f'postgresql://{wine_connection_string}')

# %%
#Check table names
engine.table_names()
# Out:
# ['wine_table']

# %%
#Convert cleaned dataframe to sql database
cleaned_wine_df.to_sql(name='wine_table', con=engine, if_exists='append', index=False)

# %%
#Confirm that the sql database has been created
pd.read_sql_query('select * from wine_table', con=engine).head()
# Out:
#   country                         designation  points  price    province  \
# 0      US  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 1      US                 Signature Selection      87   22.0  California
# 2      US                 Signature Selection      87   22.0  California
# 3      US                Alder Ridge Vineyard      86   25.0  Washington
# 4      US                         Golden Horn      86   26.0  California
#
#                  region       taster_name  \
# 0     Willamette Valley      Paul Gregutt
# 1           Paso Robles     Matt Kettmann
# 2           Paso Robles     Matt Kettmann
# 3  Columbia Valley (WA)  Sean P. Sullivan
# 4     Santa Ynez Valley     Matt Kettmann
#
#                                                title          variety  \
# 0  Sweet Cheeks 2012 Vintner's Reserve Wild Child...       Pinot Noir
# 1  Bianchi 2011 Signature Selection Merlot (Paso ...           Merlot
# 2  Bianchi 2011 Signature Selection Merlot (Paso ...           Merlot
# 3  Ram 2014 Alder Ridge Vineyard Cabernet Franc (...   Cabernet Franc
# 4  Sevtap 2015 Golden Horn Sauvignon Blanc (Santa...  Sauvignon Blanc
#
#          winery     vintage                county
# 0  Sweet Cheeks  2012-01-01     Willamette Valley
# 1       Bianchi  2011-01-01           Paso Robles
# 2       Bianchi  2011-01-01           Paso Robles
# 3           Ram  2014-01-01  Columbia Valley (WA)
# 4        Sevtap  2015-01-01     Santa Ynez Valley
